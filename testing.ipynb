# %%
from rosalind import Sequence, FASTA
Sequence("GATATATGCATATACTT").sub_locations(Sequence("ATAT"))
# Out:
# [2, 4, 10]

# %%
a = Sequence("AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUAACGGGUGA")
# a = Sequence("ACGT")
print(a.symbols_count)
print(a.gc_ratio)
# print(a.complement)
print(a.protein_string)
print(a.find_all())
# Out:
# {'A': 15, 'U': 10, 'G': 14, 'C': 12}
# 50.98039215686274
# MAMAPRTEINSTRING

# %%
FASTA.from_file('protein_test.txt').sequence
# Out:
# 'AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUAACGGGUGA'
